# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r"C:\Users\bruno\Downloads\exit-roulette-excel.csv", skiprows = 6, sep = ';')

df = df.drop([ 'percentage-stationary-staff', 'alarm?',  
               'verbose?', 'debug?', 'average-response-time',
               'agents-at-start', 'percentage-female',
               'percentage-children',
               '[step]', 'alerting-range'],1)

changes = {'precision ((count visitors with [evacuating? = false] / count visitors) * 100) 2': 'percentage_evacuating',
           '[run number]': 'run_number'}

# Renaming relevant column
df = df.rename(columns = changes)
df
# Out:
#         run_number  max-turtles-per-patch Preferred-exit-door  \
# 0                8                      1                main
# 1                8                      1                main
# 2                8                      1                main
# 3                8                      1                main
# 4                8                      1                main
# ...            ...                    ...                 ...
# 272917         600                      4         upper-right
# 272918         600                      4         upper-right
# 272919         600                      4         upper-right
# 272920         600                      4         upper-right
# 272921         600                      4         upper-right
#
#         percentage-visitors-go-to-preferred-exit  evacuation-duration  \
# 0                                             96                    0
# 1                                             96                    0
# 2                                             96                    0
# 3                                             96                    0
# 4                                             96                    0
# ...                                          ...                  ...
# 272917                                        96                  396
# 272918                                        96                  397
# 272919                                        96                  398
# 272920                                        96                  399
# 272921                                        96                  400
#
#         event-duration  people-in-building  staff-members-in-building  \
# 0                    0                 450                         50
# 1                    1                 450                         50
# 2                    2                 450                         50
# 3                    3                 450                         50
# 4                    4                 450                         50
# ...                ...                 ...                        ...
# 272917             426                   1                          0
# 272918             427                   1                          0
# 272919             428                   1                          0
# 272920             429                   1                          0
# 272921             430                   1                          0
#
#         visitors-in-building percentage_evacuating
# 0                        400                   100
# 1                        400                   100
# 2                        400                   100
# 3                        400                   100
# 4                        400                   100
# ...                      ...                   ...
# 272917                     1                     0
# 272918                     1                     0
# 272919                     1                     0
# 272920                     1                     0
# 272921                     1                     0
#
# [272922 rows x 10 columns]

# %%
runs = df.groupby(['run_number']).max()
runs.head()
# Out:
#             max-turtles-per-patch Preferred-exit-door  \
# run_number
# 1                               1                main
# 2                               1                main
# 3                               1                main
# 4                               1                main
# 5                               1                main
#
#             percentage-visitors-go-to-preferred-exit  evacuation-duration  \
# run_number
# 1                                                 96                  385
# 2                                                 96                  386
# 3                                                 96                  363
# 4                                                 96                  395
# 5                                                 96                  337
#
#             event-duration  people-in-building  staff-members-in-building  \
# run_number
# 1                      415                 450                         50
# 2                      416                 450                         50
# 3                      393                 450                         50
# 4                      425                 450                         50
# 5                      367                 450                         50
#
#             visitors-in-building        percentage_evacuating
# run_number
# 1                            400                        96,99
# 2                            400                        97,99
# 3                            400                        97,98
# 4                            400                        99,25
# 5                            400  <RuntimePrimitiveException>

# %%
evac_times = df.groupby(['Preferred-exit-door', 'max-turtles-per-patch']).mean()
evac_times
# Out:
#                                            run_number  \
# Preferred-exit-door max-turtles-per-patch
# lower-left          1                       75.210963
#                     2                      225.604252
#                     3                      375.637893
#                     4                      525.262111
# main                1                       25.559287
#                     2                      175.415830
#                     3                      325.585062
#                     4                      475.569473
# upper-right         1                      125.276686
#                     2                      275.503607
#                     3                      425.456610
#                     4                      575.453519
#
#                                            percentage-visitors-go-to-preferred-exit  \
# Preferred-exit-door max-turtles-per-patch
# lower-left          1                                                          96.0
#                     2                                                          96.0
#                     3                                                          96.0
#                     4                                                          96.0
# main                1                                                          96.0
#                     2                                                          96.0
#                     3                                                          96.0
#                     4                                                          96.0
# upper-right         1                                                          96.0
#                     2                                                          96.0
#                     3                                                          96.0
#                     4                                                          96.0
#
#                                            evacuation-duration  \
# Preferred-exit-door max-turtles-per-patch
# lower-left          1                               190.972388
#                     2                               195.213909
#                     3                               193.590302
#                     4                               192.244619
# main                1                               170.655773
#                     2                               169.513141
#                     3                               172.466587
#                     4                               169.603919
# upper-right         1                               231.702197
#                     2                               238.736961
#                     3                               235.246541
#                     4                               230.549306
#
#                                            event-duration  people-in-building  \
# Preferred-exit-door max-turtles-per-patch
# lower-left          1                          219.913018          168.797786
#                     2                          224.175406          164.575889
#                     3                          222.544465          164.878818
#                     4                          221.191009          166.121901
# main                1                          199.488604          184.551104
#                     2                          198.340261          183.001160
#                     3                          201.309698          180.910683
#                     4                          198.429618          181.214708
# upper-right         1                          260.806243          144.099615
#                     2                          267.863295          141.277882
#                     3                          264.360456          140.551431
#                     4                          259.649851          142.865488
#
#                                            staff-members-in-building  \
# Preferred-exit-door max-turtles-per-patch
# lower-left          1                                      28.287511
#                     2                                      27.399678
#                     3                                      27.877513
#                     4                                      27.734400
# main                1                                      30.838353
#                     2                                      30.650911
#                     3                                      30.663980
#                     4                                      30.688873
# upper-right         1                                      21.863854
#                     2                                      21.165865
#                     3                                      21.161249
#                     4                                      21.686912
#
#                                            visitors-in-building
# Preferred-exit-door max-turtles-per-patch
# lower-left          1                                140.510275
#                     2                                137.176210
#                     3                                137.001304
#                     4                                138.387502
# main                1                                153.712751
#                     2                                152.350250
#                     3                                150.246703
#                     4                                150.525835
# upper-right         1                                122.235761
#                     2                                120.112017
#                     3                                119.390183
#                     4                                121.178576

# %%
data = evac_times['evacuation-duration']
# Out:
# <AxesSubplot:xlabel='Preferred-exit-door'>

# %%
fig, ax = plt.subplots(figsize = (18,9))
data = evac_times['evacuation-duration']
data.unstack().plot(kind='bar', stacked=False, ax = ax, rot = 0)
ax.set_title('Evacuation time by door and turtles per patch', fontsize = 30)
ax.set_ylabel('Evacuation time', fontsize=20)
ax.set_xlabel('Preferred exit door', fontsize=20)
ax.tick_params(axis='both', which='major', labelsize=15)
#plt.xticks(rotation='horizontal')
